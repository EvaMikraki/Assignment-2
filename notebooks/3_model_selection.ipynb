# %% [markdown]
# ## Task 3 – Nested Cross Validation implementation: Assess generalization performance and select the best model type / winner algorithm.
#
# This notebook implements Task 3 of the assignment: using the `RepeatedNestedCV` class (developed in `src/rnCV.py`) to compare different classification algorithms, select the best-performing one based on robust metrics and statistical analysis (Confidence Intervals), and save the results.

# %% [markdown]
# ### Imports and Setup
#
# Imports necessary libraries including `pandas`, `numpy`, `scikit-learn` components (preprocessing, models, metrics), `LightGBM`, `SciPy` for bootstrap CIs, and standard Python modules (`os`, `sys`, `importlib`, `warnings`, `time`). The `src` directory is added to the Python path to allow importing the custom `RepeatedNestedCV` class from `rnCV.py`. The module is reloaded to incorporate recent changes and error handling for the import process is included.

# %%
# --- Imports ---
import os
import sys
import importlib
import pandas as pd
import numpy as np
import warnings
import time
import joblib # Although not used here, often used in ML workflows

# Scikit-learn imports
from sklearn.preprocessing import LabelEncoder, RobustScaler, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import make_scorer, roc_auc_score # Example metric import

# LightGBM
from lightgbm import LGBMClassifier

# Scipy for CIs
from scipy.stats import bootstrap

# --- Add src directory to path and import custom class ---
# Assuming the script/notebook is run from a location where '../src' is valid
# Adjust path as necessary depending on where you run this final script
try:
    sys.path.append(os.path.abspath("../src"))
    # Import rnCV class (adjust name if needed)
    import rnCV
    importlib.reload(rnCV) # Reload if changes were made
    from rnCV import RepeatedNestedCV
    print("Imported RepeatedNestedCV from src directory.")
except ImportError as e:
    print(f"Error: Could not import RepeatedNestedCV from ../src/rnCV.py.")
    print(f"Details: {e}")
    print("Ensure the file exists and the path is correct relative to your execution location.")
    sys.exit(1)
except FileNotFoundError:
     print("Error: Could not find the src directory or the rnCV class file.")
     sys.exit(1)
# Out:
# Imported RepeatedNestedCV from src directory.

# %% [markdown]
# ### Configuration
#
# Defines key configuration variables for the model selection process: the dataset path, target and ID column names, parameters for the Repeated Nested Cross-Validation (10 repeats, 5 outer splits, 3 inner splits), the random state for reproducibility, the scaler choice (`RobustScaler`, based on EDA), the metric for inner loop optimization (`roc_auc`), bootstrap CI settings (confidence level and number of resamples), and paths for saving the detailed rnCV results and summary statistics files. The output directory is also created if it doesn't exist.

# %%
# --- Configuration ---
DATASET_PATH = '../data/breast_cancer.csv' # Adjusted relative path
TARGET_VARIABLE = 'diagnosis'
ID_COLUMN = 'id'
N_REPEATS = 10
N_OUTER_SPLITS = 5
N_INNER_SPLITS = 3
RANDOM_STATE = 42
SCALER = RobustScaler # Using RobustScaler based on EDA
INNER_CV_METRIC = 'roc_auc' # Metric for hyperparameter tuning in rnCV

# Bootstrap settings
CONFIDENCE_LEVEL = 0.95
N_BOOTSTRAP_RESAMPLES = 5000

# Output file paths (relative to script execution location)
RESULTS_DIR = '../results' # Example: Save results in a dedicated folder
RESULTS_FILE = os.path.join(RESULTS_DIR, 'rnCV_results.csv')
STATS_FILE = os.path.join(RESULTS_DIR, 'rnCV_summary_stats_CIs.csv')

# Create results directory if it doesn't exist
os.makedirs(RESULTS_DIR, exist_ok=True)
print(f"Ensuring results directory exists: {RESULTS_DIR}")
# Out:
# Ensuring results directory exists: ../results

# %% [markdown]
# ### 1. Load and Prepare Data
#
# Loads the dataset from the configured path. Performs initial data preparation steps required before the main rnCV analysis: drops the non-informative ID column, encodes the categorical target variable (`diagnosis`) into numerical format (0/1), and separates the data into features (`X`) and the target variable (`y`). Includes error handling for file loading and target variable validation.

# %%
# --- 1. Load and Prepare Data ---
print("\n--- 1. Loading and Preparing Data ---")
try:
    df = pd.read_csv(DATASET_PATH)
    print(f"Dataset loaded successfully from: {DATASET_PATH}")
except FileNotFoundError:
    print(f"Error: Dataset file not found at {DATASET_PATH}", file=sys.stderr)
    sys.exit(1)
except Exception as e:
    print(f"An error occurred while loading the dataset: {e}", file=sys.stderr)
    sys.exit(1)

# Drop the ID column
if ID_COLUMN in df.columns:
    df = df.drop(columns=[ID_COLUMN])
    print(f"Dropped ID column: '{ID_COLUMN}'")

# Encode the target variable
if TARGET_VARIABLE in df.columns:
    if df[TARGET_VARIABLE].dtype == 'object':
        le = LabelEncoder()
        df[TARGET_VARIABLE] = le.fit_transform(df[TARGET_VARIABLE])
        print(f"Target variable '{TARGET_VARIABLE}' encoded.")
    X = df.drop(TARGET_VARIABLE, axis=1)
    y = df[TARGET_VARIABLE]
    print("Features (X) and target (y) separated.")
else:
    print(f"Error: Target variable '{TARGET_VARIABLE}' not found.", file=sys.stderr)
    sys.exit(1)
# Out:
# --- 1. Loading and Preparing Data ---
# Dataset loaded successfully from: ../data/breast_cancer.csv
# Dropped ID column: 'id'
# Target variable 'diagnosis' encoded.
# Features (X) and target (y) separated.

# %% [markdown]
# ### 2. Define Estimators and Grids
#
# Defines the six machine learning algorithms (estimators) to be compared: LR-ElasticNet, GNB, LDA, SVM, RF and LGBM. Instantiates each estimator with appropriate settings (e.g., `probability=True` for SVM, `verbosity=-1` for LGBM). Also defines the corresponding `param_grids` dictionary containing the simplified hyperparameter search spaces used during the inner loop of the rnCV for each estimator, optimized previously for runtime.

# %%
# --- 2. Define Estimators and Hyperparameter Grids ---
print("\n--- 2. Defining Estimators and Hyperparameter Grids ---")
estimators = {
    'LR_ElasticNet': LogisticRegression(penalty='elasticnet', solver='saga', max_iter=10000, random_state=RANDOM_STATE),
    'GNB': GaussianNB(),
    'LDA': LinearDiscriminantAnalysis(),
    'SVM': SVC(probability=True, random_state=RANDOM_STATE),
    'RF': RandomForestClassifier(random_state=RANDOM_STATE),
    'LGBM': LGBMClassifier(random_state=RANDOM_STATE, verbosity=-1)
}

param_grids = {
    'LR_ElasticNet': {'C': [0.01, 0.1, 1, 10], 'l1_ratio': [0, 0.25, 0.5, 0.75, 1]},
    'GNB': {'var_smoothing': np.logspace(-9, -2, 8)},
    'LDA': {'solver': ['svd', 'lsqr', 'eigen'], 'shrinkage': [None]},
    'SVM': {'C': [1, 10], 'gamma': ['scale', 0.01], 'kernel': ['rbf']},
    'RF': {'n_estimators': [75, 150], 'max_depth': [None, 20], 'min_samples_split': [5], 'min_samples_leaf': [3]},
    'LGBM': {'n_estimators': [75, 150], 'learning_rate': [0.05, 0.1], 'num_leaves': [31], 'max_depth': [-1]}
}
# Out:
# --- 2. Defining Estimators and Hyperparameter Grids ---

# %% [markdown]
# ### 3. Instantiate and Run rnCV
#
# Instantiates the `RepeatedNestedCV` class using the sequential version defined in `src/rnCV.py`, passing the prepared data, estimators, parameter grids and CV configurations. Includes logic to first check if a results file (`RESULTS_FILE`) from a previous run exists; if found, the results are loaded to avoid re-computation. Otherwise, the `rn_cv.run()` method is executed to perform the full Repeated Nested Cross-Validation. Execution time for this potentially long step is measured and printed. If the rnCV was run, the detailed results DataFrame (`results_df`) is saved to a CSV file.

# %%
# --- 3. Instantiate and Run RepeatedNestedCV ---
print("\n--- 3. Instantiating and Running RepeatedNestedCV ---")
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=UserWarning)

start_run_time = time.time()

# Check if results already exist to avoid re-running
try:
    results_df = pd.read_csv(RESULTS_FILE)
    print(f"\nLoaded existing results from {RESULTS_FILE}")
    run_needed = False
except FileNotFoundError:
    print("\nNo existing results file found. Running RepeatedNestedCV...")
    rn_cv = RepeatedNestedCV(
        X=X, y=y, estimators=estimators, param_grids=param_grids,
        n_outer_splits=N_OUTER_SPLITS, n_inner_splits=N_INNER_SPLITS, n_repeats=N_REPEATS,
        inner_cv_metric=INNER_CV_METRIC, scaler=SCALER, random_state=RANDOM_STATE
    )
    results_df = rn_cv.run()
    run_needed = True # Flag that run was executed

end_run_time = time.time()
print(f"\nTotal execution time for section 3: {(end_run_time - start_run_time) / 60:.2f} minutes")

# Save results if the run was just executed
if run_needed:
    try:
        results_df.to_csv(RESULTS_FILE, index=False)
        print(f"Full results saved to {RESULTS_FILE}")
    except Exception as e:
        print(f"Error saving results: {e}", file=sys.stderr)
# Out:
# --- 3. Instantiating and Running RepeatedNestedCV ---
#
# No existing results file found. Running RepeatedNestedCV...
# Starting Repeated Nested CV (10 repeats, 5 outer folds, 3 inner folds)
#
# --- Repeat 1/10 ---
#   Outer Fold 1/5 (Overall Fold 1)
#     Processing Estimator: LR_ElasticNet
#       Best params for LR_ElasticNet in fold 1: {'C': 0.1, 'l1_ratio': 0.25} (Inner roc_auc: 0.9917)
#       Outer test metrics for LR_ElasticNet: {'accuracy': '0.9903', 'balanced_accuracy': '0.9872', 'f1': '0.9870', 'f2': '0.9794', 'precision': '1.0000', 'recall': '0.9744', 'sensitivity': '0.9744', 'specificity': '1.0000', 'npv': '0.9846', 'mcc': '0.9795', 'roc_auc': '1.0000', 'pr_auc': '1.0000', 'log_loss': '0.0910'}
#     Processing Estimator: GNB
#       Best params for GNB in fold 1: {'var_smoothing': np.float64(0.01)} (Inner roc_auc: 0.9814)
#       Outer test metrics for GNB: {'accuracy': '0.9417', 'balanced_accuracy': '0.9431', 'f1': '0.9250', 'f2': '0.9391', 'precision': '0.9024', 'recall': '0.9487', 'sensitivity': '0.9487', 'specificity': '0.9375', 'npv': '0.9677', 'mcc': '0.8782', 'roc_auc': '0.9928', 'pr_auc': '0.9889', 'log_loss': '0.5765'}
#     Processing Estimator: LDA
#       Best params for LDA in fold 1: {'shrinkage': None, 'solver': 'svd'} (Inner roc_auc: 0.9797)
#       Outer test metrics for LDA: {'accuracy': '0.9806', 'balanced_accuracy': '0.9744', 'f1': '0.9737', 'f2': '0.9585', 'precision': '1.0000', 'recall': '0.9487', 'sensitivity': '0.9487', 'specificity': '1.0000', 'npv': '0.9697', 'mcc': '0.9592', 'roc_auc': '0.9988', 'pr_auc': '0.9981', 'log_loss': '0.0562'}
#     Processing Estimator: SVM
#       Best params for SVM in fold 1: {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'} (Inner roc_auc: 0.9914)
#       Outer test metrics for SVM: {'accuracy': '0.9903', 'balanced_accuracy': '0.9872', 'f1': '0.9870', 'f2': '0.9794', 'precision': '1.0000', 'recall': '0.9744', 'sensitivity': '0.9744', 'specificity': '1.0000', 'npv': '0.9846', 'mcc': '0.9795', 'roc_auc': '1.0000', 'pr_auc': '1.0000', 'log_loss': '0.0513'}
#     Processing Estimator: RF
#       Best params for RF in fold 1: {'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 150} (Inner roc_auc: 0.9815)
#       Outer test metrics for RF: {'accuracy': '0.9903', 'balanced_accuracy': '0.9872', 'f1': '0.9870', 'f2': '0.9794', 'precision': '1.0000', 'recall': '0.9744', 'sensitivity': '0.9744', 'specificity': '1.0000', 'npv': '0.9846', 'mcc': '0.9795', 'roc_auc': '0.9972', 'pr_auc': '0.9961', 'log_loss': '0.0929'}
#     Processing Estimator: LGBM
#       Best params for LGBM in fold 1: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 150, 'num_leaves': 31} (Inner roc_auc: 0.9848)
#       Outer test metrics for LGBM: {'accuracy': '0.9903', 'balanced_accuracy': '0.9872', 'f1': '0.9870', 'f2': '0.9794', 'precision': '1.0000', 'recall': '0.9744', 'sensitivity': '0.9744', 'specificity': '1.0000', 'npv': '0.9846', 'mcc': '0.9795', 'roc_auc': '0.9980', 'pr_auc': '0.9971', 'log_loss': '0.0490'}
#   Outer Fold 2/5 (Overall Fold 2)
#     Processing Estimator: LR_ElasticNet
#       Best params for LR_ElasticNet in fold 2: {'C': 0.1, 'l1_ratio': 0} (Inner roc_auc: 0.9963)
#       Outer test metrics for LR_ElasticNet: {'accuracy': '0.9612', 'balanced_accuracy': '0.9474', 'f1': '0.9444', 'f2': '0.9140', 'precision': '1.0000', 'recall': '0.8947', 'sensitivity': '0.8947', 'specificity': '1.0000', 'npv': '0.9420', 'mcc': '0.9181', 'roc_auc': '0.9903', 'pr_auc': '0.9861', 'log_loss': '0.1308'}
#     Processing Estimator: GNB
#       Best params for GNB in fold 2: {'var_smoothing': np.float64(1e-09)} (Inner roc_auc: 0.9871)
#       Outer test metrics for GNB: {'accuracy': '0.9029', 'balanced_accuracy': '0.8903', 'f1': '0.8649', 'f2': '0.8511', 'precision': '0.8889', 'recall': '0.8421', 'sensitivity': '0.8421', 'specificity': '0.9385', 'npv': '0.9104', 'mcc': '0.7899', 'roc_auc': '0.9688', 'pr_auc': '0.9601', 'log_loss': '1.1070'}
#     Processing Estimator: LDA
#       Best params for LDA in fold 2: {'shrinkage': None, 'solver': 'svd'} (Inner roc_auc: 0.9900)
#       Outer test metrics for LDA: {'accuracy': '0.9126', 'balanced_accuracy': '0.8816', 'f1': '0.8657', 'f2': '0.8011', 'precision': '1.0000', 'recall': '0.7632', 'sensitivity': '0.7632', 'specificity': '1.0000', 'npv': '0.8784', 'mcc': '0.8187', 'roc_auc': '0.9777', 'pr_auc': '0.9771', 'log_loss': '0.2907'}
#     Processing Estimator: SVM
#       Best params for SVM in fold 2: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'} (Inner roc_auc: 0.9969)
#       Outer test metrics for SVM: {'accuracy': '0.9417', 'balanced_accuracy': '0.9265', 'f1': '0.9167', 'f2': '0.8871', 'precision': '0.9706', 'recall': '0.8684', 'sensitivity': '0.8684', 'specificity': '0.9846', 'npv': '0.9275', 'mcc': '0.8753', 'roc_auc': '0.9879', 'pr_auc': '0.9830', 'log_loss': '0.1370'}
#     Processing Estimator: RF
#       Best params for RF in fold 2: {'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 75} (Inner roc_auc: 0.9920)
#       Outer test metrics for RF: {'accuracy': '0.9029', 'balanced_accuracy': '0.8957', 'f1': '0.8684', 'f2': '0.8684', 'precision': '0.8684', 'recall': '0.8684', 'sensitivity': '0.8684', 'specificity': '0.9231', 'npv': '0.9231', 'mcc': '0.7915', 'roc_auc': '0.9696', 'pr_auc': '0.9634', 'log_loss': '0.2055'}
#     Processing Estimator: LGBM
#       Best params for LGBM in fold 2: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75, 'num_leaves': 31} (Inner roc_auc: 0.9922)
#       Outer test metrics for LGBM: {'accuracy': '0.9417', 'balanced_accuracy': '0.9320', 'f1': '0.9189', 'f2': '0.9043', 'precision': '0.9444', 'recall': '0.8947', 'sensitivity': '0.8947', 'specificity': '0.9692', 'npv': '0.9403', 'mcc': '0.8743', 'roc_auc': '0.9757', 'pr_auc': '0.9736', 'log_loss': '0.2052'}
#   Outer Fold 3/5 (Overall Fold 3)
#     Processing Estimator: LR_ElasticNet
#       Best params for LR_ElasticNet in fold 3: {'C': 1, 'l1_ratio': 0} (Inner roc_auc: 0.9939)
#       Outer test metrics for LR_ElasticNet: {'accuracy': '0.9706', 'balanced_accuracy': '0.9712', 'f1': '0.9610', 'f2': '0.9686', 'precision': '0.9487', 'recall': '0.9737', 'sensitivity': '0.9737', 'specificity': '0.9688', 'npv': '0.9841', 'mcc': '0.9376', 'roc_auc': '0.9992', 'pr_auc': '0.9987', 'log_loss': '0.0474'}
#     Processing Estimator: GNB
#       Best params for GNB in fold 3: {'var_smoothing': np.float64(0.001)} (Inner roc_auc: 0.9751)
#       Outer test metrics for GNB: {'accuracy': '0.9608', 'balanced_accuracy': '0.9581', 'f1': '0.9474', 'f2': '0.9474', 'precision': '0.9474', 'recall': '0.9474', 'sensitivity': '0.9474', 'specificity': '0.9688', 'npv': '0.9688', 'mcc': '0.9161', 'roc_auc': '0.9938', 'pr_auc': '0.9903', 'log_loss': '0.1932'}
#     Processing Estimator: LDA
#       Best params for LDA in fold 3: {'shrinkage': None, 'solver': 'svd'} (Inner roc_auc: 0.9779)
#       Outer test metrics for LDA: {'accuracy': '0.9804', 'balanced_accuracy': '0.9737', 'f1': '0.9730', 'f2': '0.9574', 'precision': '1.0000', 'recall': '0.9474', 'sensitivity': '0.9474', 'specificity': '1.0000', 'npv': '0.9697', 'mcc': '0.9585', 'roc_auc': '0.9979', 'pr_auc': '0.9967', 'log_loss': '0.0675'}
#     Processing Estimator: SVM
#       Best params for SVM in fold 3: {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'} (Inner roc_auc: 0.9929)
#       Outer test metrics for SVM: {'accuracy': '0.9706', 'balanced_accuracy': '0.9659', 'f1': '0.9600', 'f2': '0.9524', 'precision': '0.9730', 'recall': '0.9474', 'sensitivity': '0.9474', 'specificity': '0.9844', 'npv': '0.9692', 'mcc': '0.9370', 'roc_auc': '0.9959', 'pr_auc': '0.9941', 'log_loss': '0.0857'}
#     Processing Estimator: RF
#       Best params for RF in fold 3: {'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 150} (Inner roc_auc: 0.9840)
#       Outer test metrics for RF: {'accuracy': '0.9804', 'balanced_accuracy': '0.9790', 'f1': '0.9737', 'f2': '0.9737', 'precision': '0.9737', 'recall': '0.9737', 'sensitivity': '0.9737', 'specificity': '0.9844', 'npv': '0.9844', 'mcc': '0.9581', 'roc_auc': '0.9996', 'pr_auc': '0.9993', 'log_loss': '0.0977'}
#     Processing Estimator: LGBM
#       Best params for LGBM in fold 3: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 150, 'num_leaves': 31} (Inner roc_auc: 0.9877)
#       Outer test metrics for LGBM: {'accuracy': '0.9706', 'balanced_accuracy': '0.9659', 'f1': '0.9600', 'f2': '0.9524', 'precision': '0.9730', 'recall': '0.9474', 'sensitivity': '0.9474', 'specificity': '0.9844', 'npv': '0.9692', 'mcc': '0.9370', 'roc_auc': '0.9967', 'pr_auc': '0.9947', 'log_loss': '0.1054'}
#   Outer Fold 4/5 (Overall Fold 4)
#     Processing Estimator: LR_ElasticNet
#       Best params for LR_ElasticNet in fold 4: {'C': 1, 'l1_ratio': 1} (Inner roc_auc: 0.9950)
#       Outer test metrics for LR_ElasticNet: {'accuracy': '0.9804', 'balanced_accuracy': '0.9737', 'f1': '0.9730', 'f2': '0.9574', 'precision': '1.0000', 'recall': '0.9474', 'sensitivity': '0.9474', 'specificity': '1.0000', 'npv': '0.9697', 'mcc': '0.9585', 'roc_auc': '0.9885', 'pr_auc': '0.9862', 'log_loss': '0.1069'}
#     Processing Estimator: GNB
#       Best params for GNB in fold 4: {'var_smoothing': np.float64(0.001)} (Inner roc_auc: 0.9838)
#       Outer test metrics for GNB: {'accuracy': '0.9314', 'balanced_accuracy': '0.9293', 'f1': '0.9091', 'f2': '0.9162', 'precision': '0.8974', 'recall': '0.9211', 'sensitivity': '0.9211', 'specificity': '0.9375', 'npv': '0.9524', 'mcc': '0.8542', 'roc_auc': '0.9885', 'pr_auc': '0.9817', 'log_loss': '0.6586'}
#     Processing Estimator: LDA
#       Best params for LDA in fold 4: {'shrinkage': None, 'solver': 'svd'} (Inner roc_auc: 0.9902)
#       Outer test metrics for LDA: {'accuracy': '0.9706', 'balanced_accuracy': '0.9659', 'f1': '0.9600', 'f2': '0.9524', 'precision': '0.9730', 'recall': '0.9474', 'sensitivity': '0.9474', 'specificity': '0.9844', 'npv': '0.9692', 'mcc': '0.9370', 'roc_auc': '0.9905', 'pr_auc': '0.9871', 'log_loss': '0.1083'}
#     Processing Estimator: SVM
#       Best params for SVM in fold 4: {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'} (Inner roc_auc: 0.9956)
#       Outer test metrics for SVM: {'accuracy': '0.9804', 'balanced_accuracy': '0.9790', 'f1': '0.9737', 'f2': '0.9737', 'precision': '0.9737', 'recall': '0.9737', 'sensitivity': '0.9737', 'specificity': '0.9844', 'npv': '0.9844', 'mcc': '0.9581', 'roc_auc': '0.9947', 'pr_auc': '0.9930', 'log_loss': '0.0750'}
#     Processing Estimator: RF
#       Best params for RF in fold 4: {'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 75} (Inner roc_auc: 0.9892)
#       Outer test metrics for RF: {'accuracy': '0.9510', 'balanced_accuracy': '0.9502', 'f1': '0.9351', 'f2': '0.9424', 'precision': '0.9231', 'recall': '0.9474', 'sensitivity': '0.9474', 'specificity': '0.9531', 'npv': '0.9683', 'mcc': '0.8959', 'roc_auc': '0.9951', 'pr_auc': '0.9924', 'log_loss': '0.1067'}
#     Processing Estimator: LGBM
#       Best params for LGBM in fold 4: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 150, 'num_leaves': 31} (Inner roc_auc: 0.9905)
#       Outer test metrics for LGBM: {'accuracy': '0.9608', 'balanced_accuracy': '0.9634', 'f1': '0.9487', 'f2': '0.9635', 'precision': '0.9250', 'recall': '0.9737', 'sensitivity': '0.9737', 'specificity': '0.9531', 'npv': '0.9839', 'mcc': '0.9178', 'roc_auc': '0.9955', 'pr_auc': '0.9936', 'log_loss': '0.1479'}
#   Outer Fold 5/5 (Overall Fold 5)
#     Processing Estimator: LR_ElasticNet
#       Best params for LR_ElasticNet in fold 5: {'C': 1, 'l1_ratio': 1} (Inner roc_auc: 0.9965)
#       Outer test metrics for LR_ElasticNet: {'accuracy': '0.9608', 'balanced_accuracy': '0.9474', 'f1': '0.9444', 'f2': '0.9140', 'precision': '1.0000', 'recall': '0.8947', 'sensitivity': '0.8947', 'specificity': '1.0000', 'npv': '0.9412', 'mcc': '0.9177', 'roc_auc': '0.9692', 'pr_auc': '0.9741', 'log_loss': '0.1806'}
#     Processing Estimator: GNB
#       Best params for GNB in fold 5: {'var_smoothing': np.float64(0.0001)} (Inner roc_auc: 0.9866)
#       Outer test metrics for GNB: {'accuracy': '0.9216', 'balanced_accuracy': '0.9054', 'f1': '0.8889', 'f2': '0.8602', 'precision': '0.9412', 'recall': '0.8421', 'sensitivity': '0.8421', 'specificity': '0.9688', 'npv': '0.9118', 'mcc': '0.8316', 'roc_auc': '0.9877', 'pr_auc': '0.9809', 'log_loss': '0.6993'}
#     Processing Estimator: LDA
#       Best params for LDA in fold 5: {'shrinkage': None, 'solver': 'svd'} (Inner roc_auc: 0.9919)
#       Outer test metrics for LDA: {'accuracy': '0.9216', 'balanced_accuracy': '0.8947', 'f1': '0.8824', 'f2': '0.8242', 'precision': '1.0000', 'recall': '0.7895', 'sensitivity': '0.7895', 'specificity': '1.0000', 'npv': '0.8889', 'mcc': '0.8377', 'roc_auc': '0.9831', 'pr_auc': '0.9817', 'log_loss': '0.2520'}
#     Processing Estimator: SVM
#       Best params for SVM in fold 5: {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'} (Inner roc_auc: 0.9979)
#       Outer test metrics for SVM: {'accuracy': '0.9510', 'balanced_accuracy': '0.9342', 'f1': '0.9296', 'f2': '0.8919', 'precision': '1.0000', 'recall': '0.8684', 'sensitivity': '0.8684', 'specificity': '1.0000', 'npv': '0.9275', 'mcc': '0.8975', 'roc_auc': '0.9836', 'pr_auc': '0.9865', 'log_loss': '0.1300'}
#     Processing Estimator: RF
#       Best params for RF in fold 5: {'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 150} (Inner roc_auc: 0.9902)
#       Outer test metrics for RF: {'accuracy': '0.9412', 'balanced_accuracy': '0.9317', 'f1': '0.9189', 'f2': '0.9043', 'precision': '0.9444', 'recall': '0.8947', 'sensitivity': '0.8947', 'specificity': '0.9688', 'npv': '0.9394', 'mcc': '0.8736', 'roc_auc': '0.9844', 'pr_auc': '0.9774', 'log_loss': '0.1669'}
#     Processing Estimator: LGBM
#       Best params for LGBM in fold 5: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 150, 'num_leaves': 31} (Inner roc_auc: 0.9959)
#       Outer test metrics for LGBM: {'accuracy': '0.9510', 'balanced_accuracy': '0.9342', 'f1': '0.9296', 'f2': '0.8919', 'precision': '1.0000', 'recall': '0.8684', 'sensitivity': '0.8684', 'specificity': '1.0000', 'npv': '0.9275', 'mcc': '0.8975', 'roc_auc': '0.9831', 'pr_auc': '0.9814', 'log_loss': '0.3115'}
#
# --- Repeat 2/10 ---
#   Outer Fold 1/5 (Overall Fold 6)
#     Processing Estimator: LR_ElasticNet
#       Best params for LR_ElasticNet in fold 6: {'C': 1, 'l1_ratio': 0} (Inner roc_auc: 0.9973)
#       Outer test metrics for LR_ElasticNet: {'accuracy': '0.9709', 'balanced_accuracy': '0.9615', 'f1': '0.9600', 'f2': '0.9375', 'precision': '1.0000', 'recall': '0.9231', 'sensitivity': '0.9231', 'specificity': '1.0000', 'npv': '0.9552', 'mcc': '0.9390', 'roc_auc': '0.9824', 'pr_auc': '0.9804', 'log_loss': '0.1381'}
#     Processing Estimator: GNB
#       Best params for GNB in fold 6: {'var_smoothing': np.float64(1e-09)} (Inner roc_auc: 0.9826)
#       Outer test metrics for GNB: {'accuracy': '0.8932', 'balanced_accuracy': '0.8890', 'f1': '0.8608', 'f2': '0.8673', 'precision': '0.8500', 'recall': '0.8718', 'sensitivity': '0.8718', 'specificity': '0.9062', 'npv': '0.9206', 'mcc': '0.7743', 'roc_auc': '0.9696', 'pr_auc': '0.9620', 'log_loss': '1.2438'}
#     Processing Estimator: LDA
#       Best params for LDA in fold 6: {'shrinkage': None, 'solver': 'svd'} (Inner roc_auc: 0.9868)
#       Outer test metrics for LDA: {'accuracy': '0.9126', 'balanced_accuracy': '0.8846', 'f1': '0.8696', 'f2': '0.8065', 'precision': '1.0000', 'recall': '0.7692', 'sensitivity': '0.7692', 'specificity': '1.0000', 'npv': '0.8767', 'mcc': '0.8212', 'roc_auc': '0.9776', 'pr_auc': '0.9712', 'log_loss': '0.2799'}
#     Processing Estimator: SVM
#       Best params for SVM in fold 6: {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'} (Inner roc_auc: 0.9967)
#       Outer test metrics for SVM: {'accuracy': '0.9709', 'balanced_accuracy': '0.9615', 'f1': '0.9600', 'f2': '0.9375', 'precision': '1.0000', 'recall': '0.9231', 'sensitivity': '0.9231', 'specificity': '1.0000', 'npv': '0.9552', 'mcc': '0.9390', 'roc_auc': '0.9852', 'pr_auc': '0.9843', 'log_loss': '0.1172'}
#     Processing Estimator: RF
#       Best params for RF in fold 6: {'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 150} (Inner roc_auc: 0.9867)
#       Outer test metrics for RF: {'accuracy': '0.9515', 'balanced_accuracy': '0.9459', 'f1': '0.9351', 'f2': '0.9278', 'precision': '0.9474', 'recall': '0.9231', 'sensitivity': '0.9231', 'specificity': '0.9688', 'npv': '0.9538', 'mcc': '0.8965', 'roc_auc': '0.9820', 'pr_auc': '0.9779', 'log_loss': '0.1632'}
#     Processing Estimator: LGBM
#       Best params for LGBM in fold 6: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 150, 'num_leaves': 31} (Inner roc_auc: 0.9891)
#       Outer test metrics for LGBM: {'accuracy': '0.9612', 'balanced_accuracy': '0.9537', 'f1': '0.9474', 'f2': '0.9326', 'precision': '0.9730', 'recall': '0.9231', 'sensitivity': '0.9231', 'specificity': '0.9844', 'npv': '0.9545', 'mcc': '0.9174', 'roc_auc': '0.9796', 'pr_auc': '0.9780', 'log_loss': '0.2745'}
#   Outer Fold 2/5 (Overall Fold 7)
#     Processing Estimator: LR_ElasticNet
#       Best params for LR_ElasticNet in fold 7: {'C': 1, 'l1_ratio': 0} (Inner roc_auc: 0.9919)
#       Outer test metrics for LR_ElasticNet: {'accuracy': '0.9903', 'balanced_accuracy': '0.9868', 'f1': '0.9867', 'f2': '0.9788', 'precision': '1.0000', 'recall': '0.9737', 'sensitivity': '0.9737', 'specificity': '1.0000', 'npv': '0.9848', 'mcc': '0.9793', 'roc_auc': '0.9996', 'pr_auc': '0.9993', 'log_loss': '0.0467'}
#     Processing Estimator: GNB
#       Best params for GNB in fold 7: {'var_smoothing': np.float64(0.001)} (Inner roc_auc: 0.9785)
#       Outer test metrics for GNB: {'accuracy': '0.9612', 'balanced_accuracy': '0.9528', 'f1': '0.9459', 'f2': '0.9309', 'precision': '0.9722', 'recall': '0.9211', 'sensitivity': '0.9211', 'specificity': '0.9846', 'npv': '0.9552', 'mcc': '0.9165', 'roc_auc': '0.9980', 'pr_auc': '0.9965', 'log_loss': '0.2193'}
#     Processing Estimator: LDA
#       Best params for LDA in fold 7: {'shrinkage': None, 'solver': 'svd'} (Inner roc_auc: 0.9835)
#       Outer test metrics for LDA: {'accuracy': '0.9709', 'balanced_accuracy': '0.9605', 'f1': '0.9589', 'f2': '0.9358', 'precision': '1.0000', 'recall': '0.9211', 'sensitivity': '0.9211', 'specificity': '1.0000', 'npv': '0.9559', 'mcc': '0.9383', 'roc_auc': '0.9988', 'pr_auc': '0.9980', 'log_loss': '0.0671'}
#     Processing Estimator: SVM
#       Best params for SVM in fold 7: {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'} (Inner roc_auc: 0.9922)
#       Outer test metrics for SVM: {'accuracy': '0.9806', 'balanced_accuracy': '0.9737', 'f1': '0.9730', 'f2': '0.9574', 'precision': '1.0000', 'recall': '0.9474', 'sensitivity': '0.9474', 'specificity': '1.0000', 'npv': '0.9701', 'mcc': '0.9587', 'roc_auc': '0.9992', 'pr_auc': '0.9987', 'log_loss': '0.0453'}
#     Processing Estimator: RF
#       Best params for RF in fold 7: {'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 75} (Inner roc_auc: 0.9822)
#       Outer test metrics for RF: {'accuracy': '0.9903', 'balanced_accuracy': '0.9923', 'f1': '0.9870', 'f2': '0.9948', 'precision': '0.9744', 'recall': '1.0000', 'sensitivity': '1.0000', 'specificity': '0.9846', 'npv': '1.0000', 'mcc': '0.9795', 'roc_auc': '1.0000', 'pr_auc': '1.0000', 'log_loss': '0.0679'}
#     Processing Estimator: LGBM
#       Best params for LGBM in fold 7: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 150, 'num_leaves': 31} (Inner roc_auc: 0.9872)
#       Outer test metrics for LGBM: {'accuracy': '0.9806', 'balanced_accuracy': '0.9737', 'f1': '0.9730', 'f2': '0.9574', 'precision': '1.0000', 'recall': '0.9474', 'sensitivity': '0.9474', 'specificity': '1.0000', 'npv': '0.9701', 'mcc': '0.9587', 'roc_auc': '0.9996', 'pr_auc': '0.9993', 'log_loss': '0.0333'}
#   Outer Fold 3/5 (Overall Fold 8)
#     Processing Estimator: LR_ElasticNet
#       Best params for LR_ElasticNet in fold 8: {'C': 1, 'l1_ratio': 0.25} (Inner roc_auc: 0.9951)
#       Outer test metrics for LR_ElasticNet: {'accuracy': '0.9706', 'balanced_accuracy': '0.9605', 'f1': '0.9589', 'f2': '0.9358', 'precision': '1.0000', 'recall': '0.9211', 'sensitivity': '0.9211', 'specificity': '1.0000', 'npv': '0.9552', 'mcc': '0.9380', 'roc_auc': '0.9893', 'pr_auc': '0.9852', 'log_loss': '0.1149'}
#     Processing Estimator: GNB
#       Best params for GNB in fold 8: {'var_smoothing': np.float64(0.01)} (Inner roc_auc: 0.9901)
#       Outer test metrics for GNB: {'accuracy': '0.9118', 'balanced_accuracy': '0.9030', 'f1': '0.8800', 'f2': '0.8730', 'precision': '0.8919', 'recall': '0.8684', 'sensitivity': '0.8684', 'specificity': '0.9375', 'npv': '0.9231', 'mcc': '0.8104', 'roc_auc': '0.9762', 'pr_auc': '0.9693', 'log_loss': '0.8731'}
#     Processing Estimator: LDA
#       Best params for LDA in fold 8: {'shrinkage': None, 'solver': 'svd'} (Inner roc_auc: 0.9885)
#       Outer test metrics for LDA: {'accuracy': '0.9314', 'balanced_accuracy': '0.9132', 'f1': '0.9014', 'f2': '0.8649', 'precision': '0.9697', 'recall': '0.8421', 'sensitivity': '0.8421', 'specificity': '0.9844', 'npv': '0.9130', 'mcc': '0.8541', 'roc_auc': '0.9926', 'pr_auc': '0.9875', 'log_loss': '0.1600'}
#     Processing Estimator: SVM
#       Best params for SVM in fold 8: {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'} (Inner roc_auc: 0.9941)
#       Outer test metrics for SVM: {'accuracy': '0.9608', 'balanced_accuracy': '0.9474', 'f1': '0.9444', 'f2': '0.9140', 'precision': '1.0000', 'recall': '0.8947', 'sensitivity': '0.8947', 'specificity': '1.0000', 'npv': '0.9412', 'mcc': '0.9177', 'roc_auc': '0.9934', 'pr_auc': '0.9903', 'log_loss': '0.0985'}
#     Processing Estimator: RF
#       Best params for RF in fold 8: {'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 75} (Inner roc_auc: 0.9890)
#       Outer test metrics for RF: {'accuracy': '0.9118', 'balanced_accuracy': '0.9083', 'f1': '0.8831', 'f2': '0.8901', 'precision': '0.8718', 'recall': '0.8947', 'sensitivity': '0.8947', 'specificity': '0.9219', 'npv': '0.9365', 'mcc': '0.8124', 'roc_auc': '0.9622', 'pr_auc': '0.9613', 'log_loss': '0.5046'}
#     Processing Estimator: LGBM
#       Best params for LGBM in fold 8: {'learning_rate': 0.05, 'max_depth': -1, 'n_estimators': 150, 'num_leaves': 31} (Inner roc_auc: 0.9878)
#       Outer test metrics for LGBM: {'accuracy': '0.9412', 'balanced_accuracy': '0.9317', 'f1': '0.9189', 'f2': '0.9043', 'precision': '0.9444', 'recall': '0.8947', 'sensitivity': '0.8947', 'specificity': '0.9688', 'npv': '0.9394', 'mcc': '0.8736', 'roc_auc': '0.9753', 'pr_auc': '0.9712', 'log_loss': '0.2396'}
#   Outer Fold 4/5 (Overall Fold 9)
#     Processing Estimator: LR_ElasticNet
#       Best params for LR_ElasticNet in fold 9: {'C': 0.1, 'l1_ratio': 0} (Inner roc_auc: 0.9936)
#       Outer test metrics for LR_ElasticNet: {'accuracy': '0.9608', 'balanced_accuracy': '0.9527', 'f1': '0.9459', 'f2': '0.9309', 'precision': '0.9722', 'recall': '0.9211', 'sensitivity': '0.9211', 'specificity': '0.9844', 'npv': '0.9545', 'mcc': '0.9160', 'roc_auc': '0.9988', 'pr_auc': '0.9979', 'log_loss': '0.0982'}
#     Processing Estimator: GNB
#       Best params for GNB in fold 9: {'var_smoothing': np.float64(0.001)} (Inner roc_auc: 0.9805)
#       Outer test metrics for GNB: {'accuracy': '0.9412', 'balanced_accuracy': '0.9317', 'f1': '0.9189', 'f2': '0.9043', 'precision': '0.9444', 'recall': '0.8947', 'sensitivity': '0.8947', 'specificity': '0.9688', 'npv': '0.9394', 'mcc': '0.8736', 'roc_auc': '0.9914', 'pr_auc': '0.9859', 'log_loss': '0.5275'}
#     Processing Estimator: LDA
#       Best params for LDA in fold 9: {'shrinkage': None, 'solver': 'svd'} (Inner roc_auc: 0.9861)
#       Outer test metrics for LDA: {'accuracy': '0.9510', 'balanced_accuracy': '0.9396', 'f1': '0.9315', 'f2': '0.9091', 'precision': '0.9714', 'recall': '0.8947', 'sensitivity': '0.8947', 'specificity': '0.9844', 'npv': '0.9403', 'mcc': '0.8953', 'roc_auc': '0.9967', 'pr_auc': '0.9946', 'log_loss': '0.1246'}
#     Processing Estimator: SVM
#       Best params for SVM in fold 9: {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'} (Inner roc_auc: 0.9929)
#       Outer test metrics for SVM: {'accuracy': '0.9608', 'balanced_accuracy': '0.9527', 'f1': '0.9459', 'f2': '0.9309', 'precision': '0.9722', 'recall': '0.9211', 'sensitivity': '0.9211', 'specificity': '0.9844', 'npv': '0.9545', 'mcc': '0.9160', 'roc_auc': '0.9979', 'pr_auc': '0.9966', 'log_loss': '0.0668'}
#     Processing Estimator: RF
#       Best params for RF in fold 9: {'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 75} (Inner roc_auc: 0.9890)
#       Outer test metrics for RF: {'accuracy': '0.9510', 'balanced_accuracy': '0.9342', 'f1': '0.9296', 'f2': '0.8919', 'precision': '1.0000', 'recall': '0.8684', 'sensitivity': '0.8684', 'specificity': '1.0000', 'npv': '0.9275', 'mcc': '0.8975', 'roc_auc': '0.9951', 'pr_auc': '0.9922', 'log_loss': '0.1217'}
#     Processing Estimator: LGBM
#       Best params for LGBM in fold 9: {'learning_rate': 0.05, 'max_depth': -1, 'n_estimators': 150, 'num_leaves': 31} (Inner roc_auc: 0.9819)
#       Outer test metrics for LGBM: {'accuracy': '0.9706', 'balanced_accuracy': '0.9659', 'f1': '0.9600', 'f2': '0.9524', 'precision': '0.9730', 'recall': '0.9474', 'sensitivity': '0.9474', 'specificity': '0.9844', 'npv': '0.9692', 'mcc': '0.9370', 'roc_auc': '0.9971', 'pr_auc': '0.9950', 'log_loss': '0.0683'}
#   Outer Fold 5/5 (Overall Fold 10)
#     Processing Estimator: LR_ElasticNet
#       Best params for LR_ElasticNet in fold 10: {'C': 1, 'l1_ratio': 1} (Inner roc_auc: 0.9937)
#       Outer test metrics for LR_ElasticNet: {'accuracy': '0.9706', 'balanced_accuracy': '0.9712', 'f1': '0.9610', 'f2': '0.9686', 'precision': '0.9487', 'recall': '0.9737', 'sensitivity': '0.9737', 'specificity': '0.9688', 'npv': '0.9841', 'mcc': '0.9376', 'roc_auc': '0.9988', 'pr_auc': '0.9980', 'log_loss': '0.0569'}
#     Processing Estimator: GNB
#       Best params for GNB in fold 10: {'var_smoothing': np.float64(0.001)} (Inner roc_auc: 0.9784)
#       Outer test metrics for GNB: {'accuracy': '0.9314', 'balanced_accuracy': '0.9239', 'f1': '0.9067', 'f2': '0.8995', 'precision': '0.9189', 'recall': '0.8947', 'sensitivity': '0.8947', 'specificity': '0.9531', 'npv': '0.9385', 'mcc': '0.8526', 'roc_auc': '0.9918', 'pr_auc': '0.9870', 'log_loss': '0.5160'}
#     Processing Estimator: LDA
#       Best params for LDA in fold 10: {'shrinkage': None, 'solver': 'svd'} (Inner roc_auc: 0.9911)
#       Outer test metrics for LDA: {'accuracy': '0.9804', 'balanced_accuracy': '0.9737', 'f1': '0.9730', 'f2': '0.9574', 'precision': '1.0000', 'recall': '0.9474', 'sensitivity': '0.9474', 'specificity': '1.0000', 'npv': '0.9697', 'mcc': '0.9585', 'roc_auc': '0.9955', 'pr_auc': '0.9941', 'log_loss': '0.0732'}
#     Processing Estimator: SVM
#       Best params for SVM in fold 10: {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'} (Inner roc_auc: 0.9932)
#       Outer test metrics for SVM: {'accuracy': '0.9902', 'balanced_accuracy': '0.9922', 'f1': '0.9870', 'f2': '0.9948', 'precision': '0.9744', 'recall': '1.0000', 'sensitivity': '1.0000', 'specificity': '0.9844', 'npv': '1.0000', 'mcc': '0.9794', 'roc_auc': '0.9996', 'pr_auc': '0.9993', 'log_loss': '0.0466'}
#     Processing Estimator: RF
#       Best params for RF in fold 10: {'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 150} (Inner roc_auc: 0.9864)
#       Outer test metrics for RF: {'accuracy': '0.9804', 'balanced_accuracy': '0.9790', 'f1': '0.9737', 'f2': '0.9737', 'precision': '0.9737', 'recall': '0.9737', 'sensitivity': '0.9737', 'specificity': '0.9844', 'npv': '0.9844', 'mcc': '0.9581', 'roc_auc': '0.9992', 'pr_auc': '0.9986', 'log_loss': '0.1048'}
#     Processing Estimator: LGBM
#       Best params for LGBM in fold 10: {'learning_rate': 0.05, 'max_depth': -1, 'n_estimators': 75, 'num_leaves': 31} (Inner roc_auc: 0.9874)
#       Outer test metrics for LGBM: {'accuracy': '0.9902', 'balanced_accuracy': '0.9868', 'f1': '0.9867', 'f2': '0.9788', 'precision': '1.0000', 'recall': '0.9737', 'sensitivity': '0.9737', 'specificity': '1.0000', 'npv': '0.9846', 'mcc': '0.9791', 'roc_auc': '0.9988', 'pr_auc': '0.9981', 'log_loss': '0.0705'}
#
# --- Repeat 3/10 ---
#   Outer Fold 1/5 (Overall Fold 11)
#     Processing Estimator: LR_ElasticNet
#       Best params for LR_ElasticNet in fold 11: {'C': 0.1, 'l1_ratio': 0.25} (Inner roc_auc: 0.9933)
#       Outer test metrics for LR_ElasticNet: {'accuracy': '0.9806', 'balanced_accuracy': '0.9744', 'f1': '0.9737', 'f2': '0.9585', 'precision': '1.0000', 'recall': '0.9487', 'sensitivity': '0.9487', 'specificity': '1.0000', 'npv': '0.9697', 'mcc': '0.9592', 'roc_auc': '0.9964', 'pr_auc': '0.9952', 'log_loss': '0.1000'}
#     Processing Estimator: GNB
#       Best params for GNB in fold 11: {'var_smoothing': np.float64(0.01)} (Inner roc_auc: 0.9847)
#       Outer test metrics for GNB: {'accuracy': '0.9612', 'balanced_accuracy': '0.9587', 'f1': '0.9487', 'f2': '0.9487', 'precision': '0.9487', 'recall': '0.9487', 'sensitivity': '0.9487', 'specificity': '0.9688', 'npv': '0.9688', 'mcc': '0.9175', 'roc_auc': '0.9948', 'pr_auc': '0.9923', 'log_loss': '0.2876'}
#     Processing Estimator: LDA
#       Best params for LDA in fold 11: {'shrinkage': None, 'solver': 'svd'} (Inner roc_auc: 0.9818)
#       Outer test metrics for LDA: {'accuracy': '0.9612', 'balanced_accuracy': '0.9537', 'f1': '0.9474', 'f2': '0.9326', 'precision': '0.9730', 'recall': '0.9231', 'sensitivity': '0.9231', 'specificity': '0.9844', 'npv': '0.9545', 'mcc': '0.9174', 'roc_auc': '0.9952', 'pr_auc': '0.9930', 'log_loss': '0.0869'}
#     Processing Estimator: SVM
#       Best params for SVM in fold 11: {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'} (Inner roc_auc: 0.9931)
#       Outer test metrics for SVM: {'accuracy': '0.9806', 'balanced_accuracy': '0.9744', 'f1': '0.9737', 'f2': '0.9585', 'precision': '1.0000', 'recall': '0.9487', 'sensitivity': '0.9487', 'specificity': '1.0000', 'npv': '0.9697', 'mcc': '0.9592', 'roc_auc': '0.9968', 'pr_auc': '0.9953', 'log_loss': '0.0682'}
#     Processing Estimator: RF
#       Best params for RF in fold 11: {'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 150} (Inner roc_auc: 0.9871)
#       Outer test metrics for RF: {'accuracy': '0.9417', 'balanced_accuracy': '0.9431', 'f1': '0.9250', 'f2': '0.9391', 'precision': '0.9024', 'recall': '0.9487', 'sensitivity': '0.9487', 'specificity': '0.9375', 'npv': '0.9677', 'mcc': '0.8782', 'roc_auc': '0.9900', 'pr_auc': '0.9862', 'log_loss': '0.1402'}
#     Processing Estimator: LGBM
#       Best params for LGBM in fold 11: {'learning_rate': 0.05, 'max_depth': -1, 'n_estimators': 150, 'num_leaves': 31} (Inner roc_auc: 0.9882)
#       Outer test metrics for LGBM: {'accuracy': '0.9417', 'balanced_accuracy': '0.9331', 'f1': '0.9211', 'f2': '0.9067', 'precision': '0.9459', 'recall': '0.8974', 'sensitivity': '0.8974', 'specificity': '0.9688', 'npv': '0.9394', 'mcc': '0.8757', 'roc_auc': '0.9816', 'pr_auc': '0.9785', 'log_loss': '0.1907'}
#   Outer Fold 2/5 (Overall Fold 12)
#     Processing Estimator: LR_ElasticNet
#       Best params for LR_ElasticNet in fold 12: {'C': 0.1, 'l1_ratio': 0.25} (Inner roc_auc: 0.9942)
#       Outer test metrics for LR_ElasticNet: {'accuracy': '0.9806', 'balanced_accuracy': '0.9737', 'f1': '0.9730', 'f2': '0.9574', 'precision': '1.0000', 'recall': '0.9474', 'sensitivity': '0.9474', 'specificity': '1.0000', 'npv': '0.9701', 'mcc': '0.9587', 'roc_auc': '0.9931', 'pr_auc': '0.9912', 'log_loss': '0.1264'}
#     Processing Estimator: GNB
#       Best params for GNB in fold 12: {'var_smoothing': np.float64(1e-09)} (Inner roc_auc: 0.9880)
#       Outer test metrics for GNB: {'accuracy': '0.9029', 'balanced_accuracy': '0.8957', 'f1': '0.8684', 'f2': '0.8684', 'precision': '0.8684', 'recall': '0.8684', 'sensitivity': '0.8684', 'specificity': '0.9231', 'npv': '0.9231', 'mcc': '0.7915', 'roc_auc': '0.9773', 'pr_auc': '0.9710', 'log_loss': '0.9450'}
#     Processing Estimator: LDA
#       Best params for LDA in fold 12: {'shrinkage': None, 'solver': 'svd'} (Inner roc_auc: 0.9906)
#       Outer test metrics for LDA: {'accuracy': '0.9806', 'balanced_accuracy': '0.9791', 'f1': '0.9737', 'f2': '0.9737', 'precision': '0.9737', 'recall': '0.9737', 'sensitivity': '0.9737', 'specificity': '0.9846', 'npv': '0.9846', 'mcc': '0.9583', 'roc_auc': '0.9988', 'pr_auc': '0.9981', 'log_loss': '0.0631'}
#     Processing Estimator: SVM
#       Best params for SVM in fold 12: {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'} (Inner roc_auc: 0.9933)
#       Outer test metrics for SVM: {'accuracy': '0.9709', 'balanced_accuracy': '0.9605', 'f1': '0.9589', 'f2': '0.9358', 'precision': '1.0000', 'recall': '0.9211', 'sensitivity': '0.9211', 'specificity': '1.0000', 'npv': '0.9559', 'mcc': '0.9383', 'roc_auc': '0.9935', 'pr_auc': '0.9919', 'log_loss': '0.0905'}
#     Processing Estimator: RF
#       Best params for RF in fold 12: {'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 75} (Inner roc_auc: 0.9907)
#       Outer test metrics for RF: {'accuracy': '0.9515', 'balanced_accuracy': '0.9506', 'f1': '0.9351', 'f2': '0.9424', 'precision': '0.9231', 'recall': '0.9474', 'sensitivity': '0.9474', 'specificity': '0.9538', 'npv': '0.9688', 'mcc': '0.8965', 'roc_auc': '0.9733', 'pr_auc': '0.9754', 'log_loss': '0.4666'}
#     Processing Estimator: LGBM
#       Best params for LGBM in fold 12: {'learning_rate': 0.05, 'max_depth': -1, 'n_estimators': 75, 'num_leaves': 31} (Inner roc_auc: 0.9909)
#       Outer test metrics for LGBM: {'accuracy': '0.9709', 'balanced_accuracy': '0.9605', 'f1': '0.9589', 'f2': '0.9358', 'precision': '1.0000', 'recall': '0.9211', 'sensitivity': '0.9211', 'specificity': '1.0000', 'npv': '0.9559', 'mcc': '0.9383', 'roc_auc': '0.9858', 'pr_auc': '0.9827', 'log_loss': '0.1200'}
#   Outer Fold 3/5 (Overall Fold 13)
#     Processing Estimator: LR_ElasticNet
#       Best params for LR_ElasticNet in fold 13: {'C': 0.1, 'l1_ratio': 0} (Inner roc_auc: 0.9908)
#       Outer test metrics for LR_ElasticNet: {'accuracy': '0.9706', 'balanced_accuracy': '0.9605', 'f1': '0.9589', 'f2': '0.9358', 'precision': '1.0000', 'recall': '0.9211', 'sensitivity': '0.9211', 'specificity': '1.0000', 'npv': '0.9552', 'mcc': '0.9380', 'roc_auc': '0.9967', 'pr_auc': '0.9951', 'log_loss': '0.1078'}
#     Processing Estimator: GNB
#       Best params for GNB in fold 13: {'var_smoothing': np.float64(0.01)} (Inner roc_auc: 0.9808)
#       Outer test metrics for GNB: {'accuracy': '0.9118', 'balanced_accuracy': '0.8976', 'f1': '0.8767', 'f2': '0.8556', 'precision': '0.9143', 'recall': '0.8421', 'sensitivity': '0.8421', 'specificity': '0.9531', 'npv': '0.9104', 'mcc': '0.8098', 'roc_auc': '0.9704', 'pr_auc': '0.9170', 'log_loss': '1.4073'}
#     Processing Estimator: LDA
#       Best params for LDA in fold 13: {'shrinkage': None, 'solver': 'svd'} (Inner roc_auc: 0.9806)
#       Outer test metrics for LDA: {'accuracy': '0.9216', 'balanced_accuracy': '0.9001', 'f1': '0.8857', 'f2': '0.8424', 'precision': '0.9688', 'recall': '0.8158', 'sensitivity': '0.8158', 'specificity': '0.9844', 'npv': '0.9000', 'mcc': '0.8338', 'roc_auc': '0.9942', 'pr_auc': '0.9898', 'log_loss': '0.1903'}
#     Processing Estimator: SVM
#       Best params for SVM in fold 13: {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'} (Inner roc_auc: 0.9931)
#       Outer test metrics for SVM: {'accuracy': '0.9608', 'balanced_accuracy': '0.9581', 'f1': '0.9474', 'f2': '0.9474', 'precision': '0.9474', 'recall': '0.9474', 'sensitivity': '0.9474', 'specificity': '0.9688', 'npv': '0.9688', 'mcc': '0.9161', 'roc_auc': '0.9947', 'pr_auc': '0.9915', 'log_loss': '0.0992'}
#     Processing Estimator: RF
#       Best params for RF in fold 13: {'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 150} (Inner roc_auc: 0.9843)
#       Outer test metrics for RF: {'accuracy': '0.9706', 'balanced_accuracy': '0.9659', 'f1': '0.9600', 'f2': '0.9524', 'precision': '0.9730', 'recall': '0.9474', 'sensitivity': '0.9474', 'specificity': '0.9844', 'npv': '0.9692', 'mcc': '0.9370', 'roc_auc': '0.9955', 'pr_auc': '0.9924', 'log_loss': '0.1141'}
#     Processing Estimator: LGBM
#       Best params for LGBM in fold 13: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 150, 'num_leaves': 31} (Inner roc_auc: 0.9844)
#       Outer test metrics for LGBM: {'accuracy': '0.9412', 'balanced_accuracy': '0.9317', 'f1': '0.9189', 'f2': '0.9043', 'precision': '0.9444', 'recall': '0.8947', 'sensitivity': '0.8947', 'specificity': '0.9688', 'npv': '0.9394', 'mcc': '0.8736', 'roc_auc': '0.9951', 'pr_auc': '0.9923', 'log_loss': '0.1546'}
#   Outer Fold 4/5 (Overall Fold 14)
#     Processing Estimator: LR_ElasticNet
#       Best params for LR_ElasticNet in fold 14: {'C': 1, 'l1_ratio': 0.25} (Inner roc_auc: 0.9941)
#       Outer test metrics for LR_ElasticNet: {'accuracy': '0.9608', 'balanced_accuracy': '0.9527', 'f1': '0.9459', 'f2': '0.9309', 'precision': '0.9722', 'recall': '0.9211', 'sensitivity': '0.9211', 'specificity': '0.9844', 'npv': '0.9545', 'mcc': '0.9160', 'roc_auc': '0.9926', 'pr_auc': '0.9898', 'log_loss': '0.0938'}
#     Processing Estimator: GNB
#       Best params for GNB in fold 14: {'var_smoothing': np.float64(1e-09)} (Inner roc_auc: 0.9839)
#       Outer test metrics for GNB: {'accuracy': '0.9510', 'balanced_accuracy': '0.9449', 'f1': '0.9333', 'f2': '0.9259', 'precision': '0.9459', 'recall': '0.9211', 'sensitivity': '0.9211', 'specificity': '0.9688', 'npv': '0.9538', 'mcc': '0.8948', 'roc_auc': '0.9873', 'pr_auc': '0.9839', 'log_loss': '0.5535'}
#     Processing Estimator: LDA
#       Best params for LDA in fold 14: {'shrinkage': None, 'solver': 'svd'} (Inner roc_auc: 0.9860)
#       Outer test metrics for LDA: {'accuracy': '0.9608', 'balanced_accuracy': '0.9474', 'f1': '0.9444', 'f2': '0.9140', 'precision': '1.0000', 'recall': '0.8947', 'sensitivity': '0.8947', 'specificity': '1.0000', 'npv': '0.9412', 'mcc': '0.9177', 'roc_auc': '0.9864', 'pr_auc': '0.9832', 'log_loss': '0.1610'}
#     Processing Estimator: SVM
#       Best params for SVM in fold 14: {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'} (Inner roc_auc: 0.9937)
#       Outer test metrics for SVM: {'accuracy': '0.9608', 'balanced_accuracy': '0.9474', 'f1': '0.9444', 'f2': '0.9140', 'precision': '1.0000', 'recall': '0.8947', 'sensitivity': '0.8947', 'specificity': '1.0000', 'npv': '0.9412', 'mcc': '0.9177', 'roc_auc': '0.9951', 'pr_auc': '0.9926', 'log_loss': '0.0747'}
#     Processing Estimator: RF
#       Best params for RF in fold 14: {'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 150} (Inner roc_auc: 0.9876)
#       Outer test metrics for RF: {'accuracy': '0.9706', 'balanced_accuracy': '0.9659', 'f1': '0.9600', 'f2': '0.9524', 'precision': '0.9730', 'recall': '0.9474', 'sensitivity': '0.9474', 'specificity': '0.9844', 'npv': '0.9692', 'mcc': '0.9370', 'roc_auc': '0.9910', 'pr_auc': '0.9886', 'log_loss': '0.1151'}
#     Processing Estimator: LGBM
#       Best params for LGBM in fold 14: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 150, 'num_leaves': 31} (Inner roc_auc: 0.9883)
#       Outer test metrics for LGBM: {'accuracy': '0.9706', 'balanced_accuracy': '0.9712', 'f1': '0.9610', 'f2': '0.9686', 'precision': '0.9487', 'recall': '0.9737', 'sensitivity': '0.9737', 'specificity': '0.9688', 'npv': '0.9841', 'mcc': '0.9376', 'roc_auc': '0.9930', 'pr_auc': '0.9919', 'log_loss': '0.1386'}
#   Outer Fold 5/5 (Overall Fold 15)
#     Processing Estimator: LR_ElasticNet
#       Best params for LR_ElasticNet in fold 15: {'C': 1, 'l1_ratio': 0} (Inner roc_auc: 0.9971)
#       Outer test metrics for LR_ElasticNet: {'accuracy': '0.9706', 'balanced_accuracy': '0.9605', 'f1': '0.9589', 'f2': '0.9358', 'precision': '1.0000', 'recall': '0.9211', 'sensitivity': '0.9211', 'specificity': '1.0000', 'npv': '0.9552', 'mcc': '0.9380', 'roc_auc': '0.9844', 'pr_auc': '0.9868', 'log_loss': '0.1212'}
#     Processing Estimator: GNB
#       Best params for GNB in fold 15: {'var_smoothing': np.float64(0.01)} (Inner roc_auc: 0.9861)
#       Outer test metrics for GNB: {'accuracy': '0.9412', 'balanced_accuracy': '0.9264', 'f1': '0.9167', 'f2': '0.8871', 'precision': '0.9706', 'recall': '0.8684', 'sensitivity': '0.8684', 'specificity': '0.9844', 'npv': '0.9265', 'mcc': '0.8746', 'roc_auc': '0.9901', 'pr_auc': '0.9833', 'log_loss': '0.6576'}
#     Processing Estimator: LDA
#       Best params for LDA in fold 15: {'shrinkage': None, 'solver': 'svd'} (Inner roc_auc: 0.9899)
#       Outer test metrics for LDA: {'accuracy': '0.9118', 'balanced_accuracy': '0.8816', 'f1': '0.8657', 'f2': '0.8011', 'precision': '1.0000', 'recall': '0.7632', 'sensitivity': '0.7632', 'specificity': '1.0000', 'npv': '0.8767', 'mcc': '0.8180', 'roc_auc': '0.9794', 'pr_auc': '0.9775', 'log_loss': '0.2768'}
#     Processing Estimator: SVM
#       Best params for SVM in fold 15: {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'} (Inner roc_auc: 0.9977)
#       Outer test metrics for SVM: {'accuracy': '0.9510', 'balanced_accuracy': '0.9342', 'f1': '0.9296', 'f2': '0.8919', 'precision': '1.0000', 'recall': '0.8684', 'sensitivity': '0.8684', 'specificity': '1.0000', 'npv': '0.9275', 'mcc': '0.8975', 'roc_auc': '0.9803', 'pr_auc': '0.9833', 'log_loss': '0.1345'}
#     Processing Estimator: RF
#       Best params for RF in fold 15: {'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 150} (Inner roc_auc: 0.9896)
#       Outer test metrics for RF: {'accuracy': '0.9216', 'balanced_accuracy': '0.9001', 'f1': '0.8857', 'f2': '0.8424', 'precision': '0.9688', 'recall': '0.8158', 'sensitivity': '0.8158', 'specificity': '0.9844', 'npv': '0.9000', 'mcc': '0.8338', 'roc_auc': '0.9852', 'pr_auc': '0.9775', 'log_loss': '0.1716'}
#     Processing Estimator: LGBM
#       Best params for LGBM in fold 15: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 150, 'num_leaves': 31} (Inner roc_auc: 0.9938)
#       Outer test metrics for LGBM: {'accuracy': '0.9804', 'balanced_accuracy': '0.9737', 'f1': '0.9730', 'f2': '0.9574', 'precision': '1.0000', 'recall': '0.9474', 'sensitivity': '0.9474', 'specificity': '1.0000', 'npv': '0.9697', 'mcc': '0.9585', 'roc_auc': '0.9766', 'pr_auc': '0.9778', 'log_loss': '0.2716'}
#
# --- Repeat 4/10 ---
#   Outer Fold 1/5 (Overall Fold 16)
#     Processing Estimator: LR_ElasticNet
#       Best params for LR_ElasticNet in fold 16: {'C': 0.1, 'l1_ratio': 0.25} (Inner roc_auc: 0.9938)
#       Outer test metrics for LR_ElasticNet: {'accuracy': '0.9612', 'balanced_accuracy': '0.9487', 'f1': '0.9459', 'f2': '0.9162', 'precision': '1.0000', 'recall': '0.8974', 'sensitivity': '0.8974', 'specificity': '1.0000', 'npv': '0.9412', 'mcc': '0.9190', 'roc_auc': '0.9960', 'pr_auc': '0.9944', 'log_loss': '0.1393'}
#     Processing Estimator: GNB
#       Best params for GNB in fold 16: {'var_smoothing': np.float64(0.001)} (Inner roc_auc: 0.9810)
#       Outer test metrics for GNB: {'accuracy': '0.9223', 'balanced_accuracy': '0.9075', 'f1': '0.8919', 'f2': '0.8639', 'precision': '0.9429', 'recall': '0.8462', 'sensitivity': '0.8462', 'specificity': '0.9688', 'npv': '0.9118', 'mcc': '0.8345', 'roc_auc': '0.9904', 'pr_auc': '0.9847', 'log_loss': '0.5190'}
#     Processing Estimator: LDA
#       Best params for LDA in fold 16: {'shrinkage': None, 'solver': 'svd'} (Inner roc_auc: 0.9824)
#       Outer test metrics for LDA: {'accuracy': '0.9515', 'balanced_accuracy': '0.9359', 'f1': '0.9315', 'f2': '0.8947', 'precision': '1.0000', 'recall': '0.8718', 'sensitivity': '0.8718', 'specificity': '1.0000', 'npv': '0.9275', 'mcc': '0.8992', 'roc_auc': '0.9880', 'pr_auc': '0.9843', 'log_loss': '0.1771'}
#     Processing Estimator: SVM
#       Best params for SVM in fold 16: {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'} (Inner roc_auc: 0.9951)
#       Outer test metrics for SVM: {'accuracy': '0.9612', 'balanced_accuracy': '0.9587', 'f1': '0.9487', 'f2': '0.9487', 'precision': '0.9487', 'recall': '0.9487', 'sensitivity': '0.9487', 'specificity': '0.9688', 'npv': '0.9688', 'mcc': '0.9175', 'roc_auc': '0.9948', 'pr_auc': '0.9928', 'log_loss': '0.0951'}
#     Processing Estimator: RF
#       Best params for RF in fold 16: {'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 75} (Inner roc_auc: 0.9846)
#       Outer test metrics for RF: {'accuracy': '0.9320', 'balanced_accuracy': '0.9203', 'f1': '0.9067', 'f2': '0.8854', 'precision': '0.9444', 'recall': '0.8718', 'sensitivity': '0.8718', 'specificity': '0.9688', 'npv': '0.9254', 'mcc': '0.8551', 'roc_auc': '0.9852', 'pr_auc': '0.9775', 'log_loss': '0.1654'}
#     Processing Estimator: LGBM
#       Best params for LGBM in fold 16: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75, 'num_leaves': 31} (Inner roc_auc: 0.9897)
#       Outer test metrics for LGBM: {'accuracy': '0.9320', 'balanced_accuracy': '0.9153', 'f1': '0.9041', 'f2': '0.8684', 'precision': '0.9706', 'recall': '0.8462', 'sensitivity': '0.8462', 'specificity': '0.9844', 'npv': '0.9130', 'mcc': '0.8567', 'roc_auc': '0.9804', 'pr_auc': '0.9757', 'log_loss': '0.2278'}
#   Outer Fold 2/5 (Overall Fold 17)
#     Processing Estimator: LR_ElasticNet
#       Best params for LR_ElasticNet in fold 17: {'C': 0.1, 'l1_ratio': 0} (Inner roc_auc: 0.9941)
#       Outer test metrics for LR_ElasticNet: {'accuracy': '0.9903', 'balanced_accuracy': '0.9868', 'f1': '0.9867', 'f2': '0.9788', 'precision': '1.0000', 'recall': '0.9737', 'sensitivity': '0.9737', 'specificity': '1.0000', 'npv': '0.9848', 'mcc': '0.9793', 'roc_auc': '1.0000', 'pr_auc': '1.0000', 'log_loss': '0.0789'}
#     Processing Estimator: GNB
#       Best params for GNB in fold 17: {'var_smoothing': np.float64(0.01)} (Inner roc_auc: 0.9810)
#       Outer test metrics for GNB: {'accuracy': '0.9223', 'balanced_accuracy': '0.9221', 'f1': '0.8974', 'f2': '0.9115', 'precision': '0.8750', 'recall': '0.9211', 'sensitivity': '0.9211', 'specificity': '0.9231', 'npv': '0.9524', 'mcc': '0.8357', 'roc_auc': '0.9903', 'pr_auc': '0.9846', 'log_loss': '0.4523'}
#     Processing Estimator: LDA
#       Best params for LDA in fold 17: {'shrinkage': None, 'solver': 'svd'} (Inner roc_auc: 0.9888)
#       Outer test metrics for LDA: {'accuracy': '0.9806', 'balanced_accuracy': '0.9791', 'f1': '0.9737', 'f2': '0.9737', 'precision': '0.9737', 'recall': '0.9737', 'sensitivity': '0.9737', 'specificity': '0.9846', 'npv': '0.9846', 'mcc': '0.9583', 'roc_auc': '0.9988', 'pr_auc': '0.9981', 'log_loss': '0.0501'}
#     Processing Estimator: SVM
#       Best params for SVM in fold 17: {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'} (Inner roc_auc: 0.9936)
#       Outer test metrics for SVM: {'accuracy': '1.0000', 'balanced_accuracy': '1.0000', 'f1': '1.0000', 'f2': '1.0000', 'precision': '1.0000', 'recall': '1.0000', 'sensitivity': '1.0000', 'specificity': '1.0000', 'npv': '1.0000', 'mcc': '1.0000', 'roc_auc': '1.0000', 'pr_auc': '1.0000', 'log_loss': '0.0486'}
#     Processing Estimator: RF
#       Best params for RF in fold 17: {'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 150} (Inner roc_auc: 0.9856)
#       Outer test metrics for RF: {'accuracy': '0.9806', 'balanced_accuracy': '0.9737', 'f1': '0.9730', 'f2': '0.9574', 'precision': '1.0000', 'recall': '0.9474', 'sensitivity': '0.9474', 'specificity': '1.0000', 'npv': '0.9701', 'mcc': '0.9587', 'roc_auc': '0.9992', 'pr_auc': '0.9987', 'log_loss': '0.0974'}
#     Processing Estimator: LGBM
#       Best params for LGBM in fold 17: {'learning_rate': 0.05, 'max_depth': -1, 'n_estimators': 150, 'num_leaves': 31} (Inner roc_auc: 0.9919)
#       Outer test metrics for LGBM: {'accuracy': '0.9515', 'balanced_accuracy': '0.9397', 'f1': '0.9315', 'f2': '0.9091', 'precision': '0.9714', 'recall': '0.8947', 'sensitivity': '0.8947', 'specificity': '0.9846', 'npv': '0.9412', 'mcc': '0.8958', 'roc_auc': '0.9951', 'pr_auc': '0.9926', 'log_loss': '0.1268'}
#   Outer Fold 3/5 (Overall Fold 18)
#     Processing Estimator: LR_ElasticNet
#       Best params for LR_ElasticNet in fold 18: {'C': 1, 'l1_ratio': 0} (Inner roc_auc: 0.9964)
# ...
#     Processing Estimator: LDA
#       Best params for LDA in fold 45: {'shrinkage': None, 'solver': 'svd'} (Inner roc_auc: 0.9905)
#       Outer test metrics for LDA: {'accuracy': '0.9706', 'balanced_accuracy': '0.9659', 'f1': '0.9600', 'f2': '0.9524', 'precision': '0.9730', 'recall': '0.9474', 'sensitivity': '0.9474', 'specificity': '0.9844', 'npv': '0.9692', 'mcc': '0.9370', 'roc_auc': '0.9914', 'pr_auc': '0.9889', 'log_loss': '0.1152'}
#     Processing Estimator: SVM
#       Best params for SVM in fold 45: {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'} (Inner roc_auc: 0.9940)
#       Outer test metrics for SVM: {'accuracy': '0.9706', 'balanced_accuracy': '0.9659', 'f1': '0.9600', 'f2': '0.9524', 'precision': '0.9730', 'recall': '0.9474', 'sensitivity': '0.9474', 'specificity': '0.9844', 'npv': '0.9692', 'mcc': '0.9370', 'roc_auc': '0.9918', 'pr_auc': '0.9889', 'log_loss': '0.1025'}
#     Processing Estimator: RF
#       Best params for RF in fold 45: {'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 75} (Inner roc_auc: 0.9919)
#       Outer test metrics for RF: {'accuracy': '0.9314', 'balanced_accuracy': '0.9293', 'f1': '0.9091', 'f2': '0.9162', 'precision': '0.8974', 'recall': '0.9211', 'sensitivity': '0.9211', 'specificity': '0.9375', 'npv': '0.9524', 'mcc': '0.8542', 'roc_auc': '0.9677', 'pr_auc': '0.9697', 'log_loss': '0.4897'}
#     Processing Estimator: LGBM
#       Best params for LGBM in fold 45: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 150, 'num_leaves': 31} (Inner roc_auc: 0.9907)
#       Outer test metrics for LGBM: {'accuracy': '0.9608', 'balanced_accuracy': '0.9581', 'f1': '0.9474', 'f2': '0.9474', 'precision': '0.9474', 'recall': '0.9474', 'sensitivity': '0.9474', 'specificity': '0.9688', 'npv': '0.9688', 'mcc': '0.9161', 'roc_auc': '0.9823', 'pr_auc': '0.9807', 'log_loss': '0.2484'}
#
# --- Repeat 10/10 ---
#   Outer Fold 1/5 (Overall Fold 46)
#     Processing Estimator: LR_ElasticNet
#       Best params for LR_ElasticNet in fold 46: {'C': 0.1, 'l1_ratio': 0.25} (Inner roc_auc: 0.9937)
#       Outer test metrics for LR_ElasticNet: {'accuracy': '0.9709', 'balanced_accuracy': '0.9615', 'f1': '0.9600', 'f2': '0.9375', 'precision': '1.0000', 'recall': '0.9231', 'sensitivity': '0.9231', 'specificity': '1.0000', 'npv': '0.9552', 'mcc': '0.9390', 'roc_auc': '0.9980', 'pr_auc': '0.9971', 'log_loss': '0.0986'}
#     Processing Estimator: GNB
#       Best params for GNB in fold 46: {'var_smoothing': np.float64(1e-09)} (Inner roc_auc: 0.9796)
#       Outer test metrics for GNB: {'accuracy': '0.9126', 'balanced_accuracy': '0.9147', 'f1': '0.8889', 'f2': '0.9091', 'precision': '0.8571', 'recall': '0.9231', 'sensitivity': '0.9231', 'specificity': '0.9062', 'npv': '0.9508', 'mcc': '0.8186', 'roc_auc': '0.9724', 'pr_auc': '0.9266', 'log_loss': '1.3667'}
#     Processing Estimator: LDA
#       Best params for LDA in fold 46: {'shrinkage': None, 'solver': 'svd'} (Inner roc_auc: 0.9873)
#       Outer test metrics for LDA: {'accuracy': '0.9709', 'balanced_accuracy': '0.9615', 'f1': '0.9600', 'f2': '0.9375', 'precision': '1.0000', 'recall': '0.9231', 'sensitivity': '0.9231', 'specificity': '1.0000', 'npv': '0.9552', 'mcc': '0.9390', 'roc_auc': '0.9880', 'pr_auc': '0.9873', 'log_loss': '0.1215'}
#     Processing Estimator: SVM
#       Best params for SVM in fold 46: {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'} (Inner roc_auc: 0.9940)
#       Outer test metrics for SVM: {'accuracy': '0.9612', 'balanced_accuracy': '0.9537', 'f1': '0.9474', 'f2': '0.9326', 'precision': '0.9730', 'recall': '0.9231', 'sensitivity': '0.9231', 'specificity': '0.9844', 'npv': '0.9545', 'mcc': '0.9174', 'roc_auc': '0.9968', 'pr_auc': '0.9950', 'log_loss': '0.0747'}
#     Processing Estimator: RF
#       Best params for RF in fold 46: {'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 75} (Inner roc_auc: 0.9861)
#       Outer test metrics for RF: {'accuracy': '0.9612', 'balanced_accuracy': '0.9637', 'f1': '0.9500', 'f2': '0.9645', 'precision': '0.9268', 'recall': '0.9744', 'sensitivity': '0.9744', 'specificity': '0.9531', 'npv': '0.9839', 'mcc': '0.9191', 'roc_auc': '0.9940', 'pr_auc': '0.9912', 'log_loss': '0.1159'}
#     Processing Estimator: LGBM
#       Best params for LGBM in fold 46: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 150, 'num_leaves': 31} (Inner roc_auc: 0.9903)
#       Outer test metrics for LGBM: {'accuracy': '0.9709', 'balanced_accuracy': '0.9716', 'f1': '0.9620', 'f2': '0.9694', 'precision': '0.9500', 'recall': '0.9744', 'sensitivity': '0.9744', 'specificity': '0.9688', 'npv': '0.9841', 'mcc': '0.9386', 'roc_auc': '0.9984', 'pr_auc': '0.9974', 'log_loss': '0.0660'}
#   Outer Fold 2/5 (Overall Fold 47)
#     Processing Estimator: LR_ElasticNet
#       Best params for LR_ElasticNet in fold 47: {'C': 1, 'l1_ratio': 0} (Inner roc_auc: 0.9934)
#       Outer test metrics for LR_ElasticNet: {'accuracy': '0.9903', 'balanced_accuracy': '0.9923', 'f1': '0.9870', 'f2': '0.9948', 'precision': '0.9744', 'recall': '1.0000', 'sensitivity': '1.0000', 'specificity': '0.9846', 'npv': '1.0000', 'mcc': '0.9795', 'roc_auc': '0.9988', 'pr_auc': '0.9979', 'log_loss': '0.0430'}
#     Processing Estimator: GNB
#       Best params for GNB in fold 47: {'var_smoothing': np.float64(0.01)} (Inner roc_auc: 0.9805)
#       Outer test metrics for GNB: {'accuracy': '0.9515', 'balanced_accuracy': '0.9451', 'f1': '0.9333', 'f2': '0.9259', 'precision': '0.9459', 'recall': '0.9211', 'sensitivity': '0.9211', 'specificity': '0.9692', 'npv': '0.9545', 'mcc': '0.8954', 'roc_auc': '0.9976', 'pr_auc': '0.9959', 'log_loss': '0.2032'}
#     Processing Estimator: LDA
#       Best params for LDA in fold 47: {'shrinkage': None, 'solver': 'svd'} (Inner roc_auc: 0.9762)
#       Outer test metrics for LDA: {'accuracy': '0.9709', 'balanced_accuracy': '0.9605', 'f1': '0.9589', 'f2': '0.9358', 'precision': '1.0000', 'recall': '0.9211', 'sensitivity': '0.9211', 'specificity': '1.0000', 'npv': '0.9559', 'mcc': '0.9383', 'roc_auc': '0.9988', 'pr_auc': '0.9981', 'log_loss': '0.0603'}
#     Processing Estimator: SVM
#       Best params for SVM in fold 47: {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'} (Inner roc_auc: 0.9943)
#       Outer test metrics for SVM: {'accuracy': '0.9709', 'balanced_accuracy': '0.9660', 'f1': '0.9600', 'f2': '0.9524', 'precision': '0.9730', 'recall': '0.9474', 'sensitivity': '0.9474', 'specificity': '0.9846', 'npv': '0.9697', 'mcc': '0.9373', 'roc_auc': '0.9980', 'pr_auc': '0.9968', 'log_loss': '0.0659'}
#     Processing Estimator: RF
#       Best params for RF in fold 47: {'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 150} (Inner roc_auc: 0.9877)
#       Outer test metrics for RF: {'accuracy': '0.9709', 'balanced_accuracy': '0.9605', 'f1': '0.9589', 'f2': '0.9358', 'precision': '1.0000', 'recall': '0.9211', 'sensitivity': '0.9211', 'specificity': '1.0000', 'npv': '0.9559', 'mcc': '0.9383', 'roc_auc': '0.9980', 'pr_auc': '0.9967', 'log_loss': '0.0854'}
#     Processing Estimator: LGBM
#       Best params for LGBM in fold 47: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 150, 'num_leaves': 31} (Inner roc_auc: 0.9902)
#       Outer test metrics for LGBM: {'accuracy': '0.9903', 'balanced_accuracy': '0.9868', 'f1': '0.9867', 'f2': '0.9788', 'precision': '1.0000', 'recall': '0.9737', 'sensitivity': '0.9737', 'specificity': '1.0000', 'npv': '0.9848', 'mcc': '0.9793', 'roc_auc': '0.9996', 'pr_auc': '0.9993', 'log_loss': '0.0218'}
#   Outer Fold 3/5 (Overall Fold 48)
#     Processing Estimator: LR_ElasticNet
#       Best params for LR_ElasticNet in fold 48: {'C': 1, 'l1_ratio': 0.5} (Inner roc_auc: 0.9980)
#       Outer test metrics for LR_ElasticNet: {'accuracy': '0.9510', 'balanced_accuracy': '0.9396', 'f1': '0.9315', 'f2': '0.9091', 'precision': '0.9714', 'recall': '0.8947', 'sensitivity': '0.8947', 'specificity': '0.9844', 'npv': '0.9403', 'mcc': '0.8953', 'roc_auc': '0.9720', 'pr_auc': '0.9696', 'log_loss': '0.2057'}
#     Processing Estimator: GNB
#       Best params for GNB in fold 48: {'var_smoothing': np.float64(0.01)} (Inner roc_auc: 0.9888)
#       Outer test metrics for GNB: {'accuracy': '0.9314', 'balanced_accuracy': '0.9132', 'f1': '0.9014', 'f2': '0.8649', 'precision': '0.9697', 'recall': '0.8421', 'sensitivity': '0.8421', 'specificity': '0.9844', 'npv': '0.9130', 'mcc': '0.8541', 'roc_auc': '0.9848', 'pr_auc': '0.9776', 'log_loss': '0.6892'}
#     Processing Estimator: LDA
#       Best params for LDA in fold 48: {'shrinkage': None, 'solver': 'svd'} (Inner roc_auc: 0.9976)
#       Outer test metrics for LDA: {'accuracy': '0.9216', 'balanced_accuracy': '0.8947', 'f1': '0.8824', 'f2': '0.8242', 'precision': '1.0000', 'recall': '0.7895', 'sensitivity': '0.7895', 'specificity': '1.0000', 'npv': '0.8889', 'mcc': '0.8377', 'roc_auc': '0.9556', 'pr_auc': '0.9511', 'log_loss': '0.3963'}
#     Processing Estimator: SVM
#       Best params for SVM in fold 48: {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'} (Inner roc_auc: 0.9971)
#       Outer test metrics for SVM: {'accuracy': '0.9510', 'balanced_accuracy': '0.9396', 'f1': '0.9315', 'f2': '0.9091', 'precision': '0.9714', 'recall': '0.8947', 'sensitivity': '0.8947', 'specificity': '0.9844', 'npv': '0.9403', 'mcc': '0.8953', 'roc_auc': '0.9794', 'pr_auc': '0.9785', 'log_loss': '0.1567'}
#     Processing Estimator: RF
#       Best params for RF in fold 48: {'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 75} (Inner roc_auc: 0.9905)
#       Outer test metrics for RF: {'accuracy': '0.9314', 'balanced_accuracy': '0.9186', 'f1': '0.9041', 'f2': '0.8824', 'precision': '0.9429', 'recall': '0.8684', 'sensitivity': '0.8684', 'specificity': '0.9688', 'npv': '0.9254', 'mcc': '0.8526', 'roc_auc': '0.9778', 'pr_auc': '0.9706', 'log_loss': '0.1866'}
#     Processing Estimator: LGBM
#       Best params for LGBM in fold 48: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 150, 'num_leaves': 31} (Inner roc_auc: 0.9935)
#       Outer test metrics for LGBM: {'accuracy': '0.9510', 'balanced_accuracy': '0.9342', 'f1': '0.9296', 'f2': '0.8919', 'precision': '1.0000', 'recall': '0.8684', 'sensitivity': '0.8684', 'specificity': '1.0000', 'npv': '0.9275', 'mcc': '0.8975', 'roc_auc': '0.9708', 'pr_auc': '0.9678', 'log_loss': '0.4372'}
#   Outer Fold 4/5 (Overall Fold 49)
#     Processing Estimator: LR_ElasticNet
#       Best params for LR_ElasticNet in fold 49: {'C': 0.1, 'l1_ratio': 0} (Inner roc_auc: 0.9936)
#       Outer test metrics for LR_ElasticNet: {'accuracy': '0.9706', 'balanced_accuracy': '0.9605', 'f1': '0.9589', 'f2': '0.9358', 'precision': '1.0000', 'recall': '0.9211', 'sensitivity': '0.9211', 'specificity': '1.0000', 'npv': '0.9552', 'mcc': '0.9380', 'roc_auc': '0.9930', 'pr_auc': '0.9907', 'log_loss': '0.1204'}
#     Processing Estimator: GNB
#       Best params for GNB in fold 49: {'var_smoothing': np.float64(0.01)} (Inner roc_auc: 0.9883)
#       Outer test metrics for GNB: {'accuracy': '0.9118', 'balanced_accuracy': '0.9030', 'f1': '0.8800', 'f2': '0.8730', 'precision': '0.8919', 'recall': '0.8684', 'sensitivity': '0.8684', 'specificity': '0.9375', 'npv': '0.9231', 'mcc': '0.8104', 'roc_auc': '0.9725', 'pr_auc': '0.9648', 'log_loss': '0.7952'}
#     Processing Estimator: LDA
#       Best params for LDA in fold 49: {'shrinkage': None, 'solver': 'svd'} (Inner roc_auc: 0.9865)
#       Outer test metrics for LDA: {'accuracy': '0.9216', 'balanced_accuracy': '0.9001', 'f1': '0.8857', 'f2': '0.8424', 'precision': '0.9688', 'recall': '0.8158', 'sensitivity': '0.8158', 'specificity': '0.9844', 'npv': '0.9000', 'mcc': '0.8338', 'roc_auc': '0.9963', 'pr_auc': '0.9932', 'log_loss': '0.1357'}
#     Processing Estimator: SVM
#       Best params for SVM in fold 49: {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'} (Inner roc_auc: 0.9944)
#       Outer test metrics for SVM: {'accuracy': '0.9706', 'balanced_accuracy': '0.9605', 'f1': '0.9589', 'f2': '0.9358', 'precision': '1.0000', 'recall': '0.9211', 'sensitivity': '0.9211', 'specificity': '1.0000', 'npv': '0.9552', 'mcc': '0.9380', 'roc_auc': '0.9934', 'pr_auc': '0.9911', 'log_loss': '0.0957'}
#     Processing Estimator: RF
#       Best params for RF in fold 49: {'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 75} (Inner roc_auc: 0.9895)
#       Outer test metrics for RF: {'accuracy': '0.9118', 'balanced_accuracy': '0.9137', 'f1': '0.8861', 'f2': '0.9067', 'precision': '0.8537', 'recall': '0.9211', 'sensitivity': '0.9211', 'specificity': '0.9062', 'npv': '0.9508', 'mcc': '0.8158', 'roc_auc': '0.9683', 'pr_auc': '0.9667', 'log_loss': '0.4849'}
#     Processing Estimator: LGBM
#       Best params for LGBM in fold 49: {'learning_rate': 0.05, 'max_depth': -1, 'n_estimators': 150, 'num_leaves': 31} (Inner roc_auc: 0.9878)
#       Outer test metrics for LGBM: {'accuracy': '0.9510', 'balanced_accuracy': '0.9449', 'f1': '0.9333', 'f2': '0.9259', 'precision': '0.9459', 'recall': '0.9211', 'sensitivity': '0.9211', 'specificity': '0.9688', 'npv': '0.9538', 'mcc': '0.8948', 'roc_auc': '0.9877', 'pr_auc': '0.9834', 'log_loss': '0.1749'}
#   Outer Fold 5/5 (Overall Fold 50)
#     Processing Estimator: LR_ElasticNet
#       Best params for LR_ElasticNet in fold 50: {'C': 1, 'l1_ratio': 0} (Inner roc_auc: 0.9942)
#       Outer test metrics for LR_ElasticNet: {'accuracy': '0.9804', 'balanced_accuracy': '0.9790', 'f1': '0.9737', 'f2': '0.9737', 'precision': '0.9737', 'recall': '0.9737', 'sensitivity': '0.9737', 'specificity': '0.9844', 'npv': '0.9844', 'mcc': '0.9581', 'roc_auc': '0.9963', 'pr_auc': '0.9947', 'log_loss': '0.0639'}
#     Processing Estimator: GNB
#       Best params for GNB in fold 50: {'var_smoothing': np.float64(0.001)} (Inner roc_auc: 0.9760)
#       Outer test metrics for GNB: {'accuracy': '0.9510', 'balanced_accuracy': '0.9449', 'f1': '0.9333', 'f2': '0.9259', 'precision': '0.9459', 'recall': '0.9211', 'sensitivity': '0.9211', 'specificity': '0.9688', 'npv': '0.9538', 'mcc': '0.8948', 'roc_auc': '0.9852', 'pr_auc': '0.9818', 'log_loss': '0.5102'}
#     Processing Estimator: LDA
#       Best params for LDA in fold 50: {'shrinkage': None, 'solver': 'svd'} (Inner roc_auc: 0.9847)
#       Outer test metrics for LDA: {'accuracy': '0.9706', 'balanced_accuracy': '0.9659', 'f1': '0.9600', 'f2': '0.9524', 'precision': '0.9730', 'recall': '0.9474', 'sensitivity': '0.9474', 'specificity': '0.9844', 'npv': '0.9692', 'mcc': '0.9370', 'roc_auc': '0.9934', 'pr_auc': '0.9908', 'log_loss': '0.1071'}
#     Processing Estimator: SVM
#       Best params for SVM in fold 50: {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'} (Inner roc_auc: 0.9924)
#       Outer test metrics for SVM: {'accuracy': '0.9804', 'balanced_accuracy': '0.9790', 'f1': '0.9737', 'f2': '0.9737', 'precision': '0.9737', 'recall': '0.9737', 'sensitivity': '0.9737', 'specificity': '0.9844', 'npv': '0.9844', 'mcc': '0.9581', 'roc_auc': '0.9988', 'pr_auc': '0.9981', 'log_loss': '0.0652'}
#     Processing Estimator: RF
#       Best params for RF in fold 50: {'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 150} (Inner roc_auc: 0.9884)
#       Outer test metrics for RF: {'accuracy': '0.9608', 'balanced_accuracy': '0.9527', 'f1': '0.9459', 'f2': '0.9309', 'precision': '0.9722', 'recall': '0.9211', 'sensitivity': '0.9211', 'specificity': '0.9844', 'npv': '0.9545', 'mcc': '0.9160', 'roc_auc': '0.9881', 'pr_auc': '0.9868', 'log_loss': '0.1374'}
#     Processing Estimator: LGBM
#       Best params for LGBM in fold 50: {'learning_rate': 0.05, 'max_depth': -1, 'n_estimators': 150, 'num_leaves': 31} (Inner roc_auc: 0.9844)
#       Outer test metrics for LGBM: {'accuracy': '0.9706', 'balanced_accuracy': '0.9659', 'f1': '0.9600', 'f2': '0.9524', 'precision': '0.9730', 'recall': '0.9474', 'sensitivity': '0.9474', 'specificity': '0.9844', 'npv': '0.9692', 'mcc': '0.9370', 'roc_auc': '0.9877', 'pr_auc': '0.9869', 'log_loss': '0.1090'}
#
# Repeated Nested Cross-Validation finished.
#
# Total execution time for section 3: 27.48 minutes
# Full results saved to ../results/rnCV_results.csv

# %% [markdown]
# ### 4. Analyze Results with CIs
#
# Analyzes the performance results stored in `results_df` (either loaded or generated). Defines the list of performance metrics to analyze. Includes the helper function `median_ci` to calculate the median and 95% bootstrap confidence interval for a given metric's scores across the 50 outer folds. Checks if a pre-calculated statistics file (`STATS_FILE`) exists; if not, it computes the medians and CIs for all specified metrics and estimators using the `median_ci` function and saves this summary (`final_stats_df`) to a CSV file. Finally, it sorts the summary statistics DataFrame by median ROC AUC and prints it for review.

# %%
# --- 4. Analyze Results (with Confidence Intervals) ---
print("\n--- 4. Analyzing Results with Confidence Intervals ---")
if results_df.empty:
    print("Error: Results DataFrame is empty. Cannot analyze.", file=sys.stderr)
    sys.exit(1)

metrics_to_analyze = [
    'roc_auc', 'mcc', 'balanced_accuracy', 'f1', 'pr_auc',
    'recall', 'specificity', 'precision', 'npv'
]

def median_ci(data, metric, confidence_level=CONFIDENCE_LEVEL):
    data_array = data[metric].dropna().values
    if len(data_array) < 2:
        return pd.Series({'median': np.nan, 'ci_lower': np.nan, 'ci_upper': np.nan})
    res = bootstrap((data_array,), np.median, confidence_level=confidence_level,
                    n_resamples=N_BOOTSTRAP_RESAMPLES, method='percentile',
                    random_state=RANDOM_STATE)
    return pd.Series({
        'median': np.median(data_array),
        'ci_lower': res.confidence_interval.low,
        'ci_upper': res.confidence_interval.high
    })

# Check if stats file exists
try:
    final_stats_df = pd.read_csv(STATS_FILE, index_col='estimator')
    print(f"\nLoaded existing summary stats with CIs from {STATS_FILE}")
    calc_needed = False
except FileNotFoundError:
    print(f"\nNo existing stats file found. Calculating Median and {CONFIDENCE_LEVEL*100:.0f}% CIs...")
    analysis_results = {}
    grouped_results = results_df.groupby('estimator')
    for metric in metrics_to_analyze:
        # Use include_groups=False to avoid the deprecation warning if pandas version is recent
        try:
             metric_stats = grouped_results.apply(median_ci, metric=metric, confidence_level=CONFIDENCE_LEVEL, include_groups=False)
        except TypeError: # Older pandas might not have include_groups
             metric_stats = grouped_results.apply(median_ci, metric=metric, confidence_level=CONFIDENCE_LEVEL)

        metric_stats = metric_stats.rename(columns={
            'median': f'{metric}_median', 'ci_lower': f'{metric}_ci_lower', 'ci_upper': f'{metric}_ci_upper'
        })
        analysis_results[metric] = metric_stats
    final_stats_df = pd.concat(analysis_results.values(), axis=1)
    calc_needed = True # Flag that calculation was done

# Save stats if they were just calculated
if calc_needed:
     try:
        final_stats_df.to_csv(STATS_FILE)
        print(f"Summary stats with CIs saved to {STATS_FILE}")
     except Exception as e:
        print(f"Error saving summary stats: {e}", file=sys.stderr)


# Sort and display
final_stats_df = final_stats_df.sort_values(by='roc_auc_median', ascending=False)
print("\nMedian Performance Metrics & 95% CIs per Estimator (across all outer folds):")
pd.set_option('display.float_format', '{:.4f}'.format)
print(final_stats_df)
# Out:
# --- 4. Analyzing Results with Confidence Intervals ---
#
# No existing stats file found. Calculating Median and 95% CIs...
# Summary stats with CIs saved to ../results/rnCV_summary_stats_CIs.csv
#
# Median Performance Metrics & 95% CIs per Estimator (across all outer folds):
#                roc_auc_median  roc_auc_ci_lower  roc_auc_ci_upper  mcc_median  \
# estimator
# SVM                    0.9955            0.9937            0.9979      0.9380
# LR_ElasticNet          0.9947            0.9929            0.9966      0.9380
# LDA                    0.9928            0.9872            0.9951      0.8986
# LGBM                   0.9913            0.9877            0.9955      0.9174
# RF                     0.9901            0.9852            0.9930      0.8959
# GNB                    0.9875            0.9844            0.9904      0.8526
#
#                mcc_ci_lower  mcc_ci_upper  balanced_accuracy_median  \
# estimator
# SVM                  0.9177        0.9581                    0.9637
# LR_ElasticNet        0.9280        0.9581                    0.9637
# LDA                  0.8796        0.9177                    0.9396
# LGBM                 0.8959        0.9373                    0.9571
# RF                   0.8782        0.9063                    0.9455
# GNB                  0.8357        0.8736                    0.9218
#
#                balanced_accuracy_ci_lower  balanced_accuracy_ci_upper  \
# estimator
# SVM                                0.9585                      0.9737
# LR_ElasticNet                      0.9593                      0.9737
# LDA                                0.9265                      0.9480
# LGBM                               0.9437                      0.9659
# RF                                 0.9396                      0.9502
# GNB                                0.9140                      0.9305
#
#                f1_median  ...  recall_ci_upper  specificity_median  \
# estimator                 ...
# SVM               0.9600  ...           0.9474              1.0000
# LR_ElasticNet     0.9600  ...           0.9474              1.0000
# LDA               0.9315  ...           0.8961              1.0000
# LGBM              0.9474  ...           0.9474              0.9844
# RF                0.9342  ...           0.9474              0.9688
# GNB               0.9041  ...           0.9211              0.9688
#
#                specificity_ci_lower  specificity_ci_upper  precision_median  \
# estimator
# SVM                          0.9846                1.0000            1.0000
# LR_ElasticNet                0.9844                1.0000            1.0000
# LDA                          0.9846                1.0000            1.0000
# LGBM                         0.9688                0.9844            0.9710
# RF                           0.9538                0.9844            0.9459
# GNB                          0.9531                0.9688            0.9412
#
#                precision_ci_lower  precision_ci_upper  npv_median  \
# estimator
# SVM                        0.9737              1.0000      0.9692
# LR_ElasticNet              0.9737              1.0000      0.9690
# LDA                        0.9733              1.0000      0.9403
# LGBM                       0.9487              0.9730      0.9680
# RF                         0.9268              0.9714      0.9549
# GNB                        0.9130              0.9444      0.9385
#
#                npv_ci_lower  npv_ci_upper
# estimator
# SVM                  0.9552        0.9697
# LR_ElasticNet        0.9552        0.9697
# LDA                  0.9209        0.9416
# LGBM                 0.9475        0.9695
# RF                   0.9523        0.9683
# GNB                  0.9248        0.9524
#
# [6 rows x 27 columns]

# %% [markdown]
# ### 5. Select Winner Algorithm
#
# Selects the final "winner" algorithm based on the statistical analysis performed in the previous step. Retrieves the name of the second-ranked algorithm (`LR_ElasticNet`, index 1) from the sorted `final_stats_df`, as the analysis showed its performance was statistically indistinguishable from the top-ranked algorithm (`SVM`, index 0) based on overlapping confidence intervals for key metrics. Prints the selected winner and a brief justification referencing the statistical tie and secondary factors like model simplicity and interpretability. Resets warnings and display options.

# %%
# --- 5. Select Winner Algorithm ---
print("\n--- 5. Selecting Winner Algorithm ---")
if final_stats_df.empty:
    print("Error: Cannot select winner, stats DataFrame is empty.", file=sys.stderr)
    sys.exit(1)

# Select the winner based on analysis (LR_ElasticNet is index 1 in the sorted list)
try:
    winner_algorithm_name = final_stats_df.index[1]
    print(f"\nSelected Winner Algorithm: {winner_algorithm_name}")
    print("Justification: SVM (index 0) and LR_ElasticNet (index 1) showed statistically indistinguishable performance")
    print("based on overlapping 95% CIs for key metrics (ROC AUC, MCC, Balanced Accuracy, Recall).")
    print("LR_ElasticNet was chosen due to its relative simplicity and potentially better interpretability compared to SVM.")
except IndexError:
    print("Error: Could not select winner algorithm. Check final_stats_df content.", file=sys.stderr)
    sys.exit(1)

# Reset warnings and display options
warnings.filterwarnings('default')
pd.reset_option('display.float_format')

print("\n--- Task 3 Script Complete ---")
# Out:
# --- 5. Selecting Winner Algorithm ---
#
# Selected Winner Algorithm: LR_ElasticNet
# Justification: SVM (index 0) and LR_ElasticNet (index 1) showed statistically indistinguishable performance
# based on overlapping 95% CIs for key metrics (ROC AUC, MCC, Balanced Accuracy, Recall).
# LR_ElasticNet was chosen due to its relative simplicity and potentially better interpretability compared to SVM.
#
# --- Task 3 Script Complete ---
